# %%
import scanpy as sc
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad('control_annotated_data.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 96303 × 45947
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age'
#     var: 'HGNC_Alt_GeneID'

# %%
sc.pp.filter_cells(adata, min_genes=100, inplace=True)

# %%
sc.pp.filter_genes(adata, min_cells=3, inplace=True)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata = adata[:, adata.var.highly_variable]

# %%
print(adata)
# Out:
# View of AnnData object with n_obs × n_vars = 96303 × 4443
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age', 'n_genes'
#     var: 'HGNC_Alt_GeneID', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca(adata, color='cell_type_category')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['cell_type_category'])

# %%
sc.pl.umap(adata, color=['manuscript_id'])

# %%
print(adata.obsm['X_pca'].shape)
# Out:
# (96303, 50)

# %%
print(adata.obsm['X_umap'])
# Out:
# [[-7.219336    9.850314  ]
#  [ 1.7723752  14.367751  ]
#  [ 2.0271776  -2.662155  ]
#  ...
#  [-2.7403624   7.3163047 ]
#  [-3.04603    -4.6976056 ]
#  [ 0.41213548 14.007571  ]]

# %%
sc.pl.umap(adata, color=['age'])

# %%
X = adata.obsm['X_pca'][:,0:40] #take first 40 pca as features
y = pd.factorize(adata.obs['cell_type_category'])[0] #factorize categories

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0) #split training set and testing set

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(penalty='l2', tol=1e-6, max_iter=int(1e6))
LR.fit(X_train, y_train)
print("Training Accuracy: ", LR.score(X_train, y_train))
print("Testing Accuracy: ", LR.score(X_test, y_test))
# Out:
# Training Accuracy:  0.9930427817005875
# Testing Accuracy:  0.9919005918798242

# %%
# import data again
adata = sc.read_h5ad('control_annotated_data.h5ad')
sc.pp.filter_cells(adata, min_genes=100, inplace=True)
sc.pp.filter_genes(adata, min_cells=3, inplace=True)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
adata = adata[:, adata.var.highly_variable]
print(adata)
# Out:
# View of AnnData object with n_obs × n_vars = 96303 × 4443
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age', 'n_genes'
#     var: 'HGNC_Alt_GeneID', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
subjects = pd.unique(adata.obs['subject_id']).to_list()
subjects
# Out:
# ['001C',
#  '002C',
#  '003C',
#  '222C',
#  '034C',
#  '065C',
#  '081C',
#  '084C',
#  '092C',
#  '098C',
#  '133C',
#  '1372C',
#  '137C',
#  '160C',
#  '192C',
#  '208C',
#  '218C',
#  '226C',
#  '244C',
#  '253C',
#  '296C',
#  '388C',
#  '396C',
#  '439C',
#  '454C',
#  '465C',
#  '483C',
#  '484C']

# %%
import anndata as ad
from sklearn.linear_model import LogisticRegression

# %%
print(adata.obsm['X_pca'].shape)
# Out:
# (96303, 50)

# %%
train_acc = []
val_acc = []
for s in subjects:
    # test = adata[num[0]:num[-1]+1]
    # train_1 = adata[:num[0]]
    # train_2 = adata[num[-1]+1:]
    # train = ad.concat([train_1, train_2])
    train = adata[adata.obs['subject_id'] != s, :]
    test = adata[adata.obs['subject_id'] == s, :]
    # print(test,train,adata)
    #sc.tl.pca(train, svd_solver='arpack')
    #sc.tl.pca(test, svd_solver='arpack')
    X_train = train.obsm['X_pca'][:,0:40] #take first 40 pca as features
    y_train = pd.factorize(train.obs['cell_type_category'])[0] #factorize categories
    X_test = test.obsm['X_pca'][:,0:40] 
    y_test = pd.factorize(test.obs['cell_type_category'])[0]
    print("Training")
    LR = LogisticRegression(penalty='l2', tol=1e-6, max_iter=int(1e6))
    LR.fit(X_train, y_train)
    print(f"subject: {s}")
    train_acc.append(LR.score(X_train, y_train))
    val_acc.append(LR.score(X_test, y_test))
    print("Training Accuracy: ", train_acc[-1])
    print("Testing Accuracy: ", val_acc[-1])
# Out:
# Training
# subject: 001C
# Training Accuracy:  0.9927785601592529
# Testing Accuracy:  0.8131041890440387
# Training
# subject: 002C
# Training Accuracy:  0.9928349528780478
# Testing Accuracy:  0.8728571428571429
# Training
# subject: 003C
# Training Accuracy:  0.9931928093663497
# Testing Accuracy:  0.7875722543352601
# Training
# subject: 222C
# Training Accuracy:  0.9930156741266692
# Testing Accuracy:  0.0011869436201780415
# Training
# subject: 034C
# Training Accuracy:  0.9927926608575582
# Testing Accuracy:  0.9631728045325779
# Training
# subject: 065C
# Training Accuracy:  0.9928934547765303
# Testing Accuracy:  0.9484864577801381
# Training
# subject: 081C
# Training Accuracy:  0.9928767008319258
# Testing Accuracy:  0.9490835030549898
# Training
# subject: 084C
# Training Accuracy:  0.9927785778389998
# Testing Accuracy:  0.9979035639412998
# Training
# subject: 092C
# Training Accuracy:  0.992487823969386
# Testing Accuracy:  0.9988423246121787
# Training
# subject: 098C
# Training Accuracy:  0.9931543824586794
# Testing Accuracy:  0.679004329004329
# Training
# subject: 133C
# Training Accuracy:  0.9925459042365251
# Testing Accuracy:  0.6956572495914078
# Training
# subject: 1372C
# Training Accuracy:  0.9926396824704496
# Testing Accuracy:  0.008269858541893362
# Training
# subject: 137C
# Training Accuracy:  0.9927914882901032
# Testing Accuracy:  0.015015015015015015
# Training
# subject: 160C
# Training Accuracy:  0.9927202981626382
# Testing Accuracy:  0.8784408720546135
# Training
# subject: 192C
# Training Accuracy:  0.9927065835816852
# Testing Accuracy:  0.8987090367428004
# Training
# subject: 208C
# Training Accuracy:  0.9927642328177053
# Testing Accuracy:  0.9516837481698389
# Training
# subject: 218C
# Training Accuracy:  0.9925120244862266
# Testing Accuracy:  0.8125647936968692
# Training
# subject: 226C
# Training Accuracy:  0.9927892762396718
# Testing Accuracy:  0.9144932935916542
# Training
# subject: 244C
# Training Accuracy:  0.9928747516564902
# Testing Accuracy:  0.006024096385542169
# Training
# subject: 253C
# Training Accuracy:  0.9927536231884058
# Testing Accuracy:  0.9978835978835979
# Training
# subject: 296C
# Training Accuracy:  0.9928817204301075
# Testing Accuracy:  0.7577959430820467
# Training
# subject: 388C
# Training Accuracy:  0.9927140061266168
# Testing Accuracy:  0.9335373852208133
# Training
# subject: 396C
# Training Accuracy:  0.9929183984847688
# Testing Accuracy:  0.777602523659306
# Training
# subject: 439C
# Training Accuracy:  0.9931991111709649
# Testing Accuracy:  0.9547033486174795
# Training
# subject: 454C
# Training Accuracy:  0.9928000840866092
# Testing Accuracy:  0.06620808254514188
# Training
# subject: 465C
# Training Accuracy:  0.9927946968969161
# Testing Accuracy:  0.9584286803966438
# Training
# subject: 483C
# Training Accuracy:  0.9926915028097347
# Testing Accuracy:  0.945983379501385
# Training
# subject: 484C
# Training Accuracy:  0.9928776275566481
# Testing Accuracy:  0.9873873873873874

# %%
import numpy as np
print("Average Training Accuracy: ", np.mean(train_acc))
print("Averahe Testing Accuracy: ", np.mean(val_acc))
# Out:
# Average Training Accuracy:  0.9928135932127023
# Averahe Testing Accuracy:  0.7347000644594847

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
train_acc = []
val_acc = []
for s in subjects:
    # test = adata[num[0]:num[-1]+1]
    # train_1 = adata[:num[0]]
    # train_2 = adata[num[-1]+1:]
    # train = ad.concat([train_1, train_2])
    train = adata[adata.obs['subject_id'] != s, :]
    test = adata[adata.obs['subject_id'] == s, :]
    # print(test,train,adata)
    #sc.tl.pca(train, svd_solver='arpack')
    #sc.tl.pca(test, svd_solver='arpack')
    X_train = train.obsm['X_pca'][:,0:40] #take first 40 pca as features
    y_train = pd.factorize(train.obs['manuscript_id'])[0] #factorize categories
    X_test = test.obsm['X_pca'][:,0:40] 
    y_test = pd.factorize(test.obs['manuscript_id'])[0]
    print("Training")
    LR = make_pipeline(StandardScaler(), LogisticRegression(penalty='l2', tol=1e-4, max_iter=400, solver='liblinear'))
    LR.fit(X_train, y_train)
    print(f"subject: {s}")
    train_acc.append(LR.score(X_train, y_train))
    val_acc.append(LR.score(X_test, y_test))
    print("Training Accuracy: ", train_acc[-1])
    print("Testing Accuracy: ", val_acc[-1])
# Out:
# Training
# subject: 001C
# Training Accuracy:  0.9164028335151047
# Testing Accuracy:  0.24758324382384533
# Training
# subject: 002C
# Training Accuracy:  0.9159022206416116
# Testing Accuracy:  0.1657142857142857
# Training
# subject: 003C
# Training Accuracy:  0.9166980817078293
# Testing Accuracy:  0.13005780346820808
# Training
# subject: 222C
# Training Accuracy:  0.9170234241759772
# Testing Accuracy:  0.2534124629080119
# Training
# subject: 034C
# Training Accuracy:  0.9153529922487107
# Testing Accuracy:  0.009915014164305949
# Training
# subject: 065C
# Training Accuracy:  0.9153463249311586
# Testing Accuracy:  0.0015932023366967605
# Training
# subject: 081C
# Training Accuracy:  0.9155799876207761
# Testing Accuracy:  0.002036659877800407
# Training
# subject: 084C
# Training Accuracy:  0.9157326821530691
# Testing Accuracy:  0.4088050314465409
# Training
# subject: 098C
# Training Accuracy:  0.9141426323466915
# Testing Accuracy:  0.07932900432900433
# Training

# %%
import numpy as np
print("Average Training Accuracy: ", np.mean(train_acc))
print("Averahe Testing Accuracy: ", np.mean(val_acc))
# Out:
# Average Training Accuracy:  0.9927928706109157
# Averahe Testing Accuracy:  0.615554337099039

# %% [raw]
# # take '388C' as the validation individual
# num = []
# for i in range(adata.obs.shape[0]):
#     if adata.obs['subject_id'][i] == '388C':
#         num.append(i)
# print("range of '388C': ", num[0], "-", num[-1])

# %% [raw]
# test = adata[num[0]:num[-1]+1]
# train_1 = adata[:num[0]]
# train_2 = adata[num[-1]+1:]
# train = ad.concat([train_1, train_2])
# print(test,train,adata)

# %% [raw]
# sc.tl.pca(train, svd_solver='arpack')
# sc.tl.pca(test, svd_solver='arpack')

# %% [raw]
# X_train = train.obsm['X_pca'][:,0:40] #take first 40 pca as features
# y_train = pd.factorize(train.obs['cell_type_category'])[0] #factorize categories
# X_test = test.obsm['X_pca'][:,0:40]
# y_test = pd.factorize(test.obs['cell_type_category'])[0]

# %% [raw]
# from sklearn.linear_model import LogisticRegression
# LR = LogisticRegression(penalty='l2', tol=1e-6, max_iter=int(1e6))
# LR.fit(X_train, y_train)
# print("Training Accuracy: ", LR.score(X_train, y_train))
# print("Testing Accuracy: ", LR.score(X_test, y_test))
