# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad('control_annotated_data.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 96303 × 45947
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age'
#     var: 'HGNC_Alt_GeneID'

# %%
# Example Subsetting For Controls
controls = adata[adata.obs['subject_id'].str[-1:] == 'C']

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %% [markdown]
# Not sure if there's any specific gene of interest here. TODO: identify genes of interest and/or plot what PCA looks like when we color by each of the genes in the dataset.

# %%
adata.var_names
# Out:
# Index(['ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419',
#        'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938',
#        'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084',
#        'ENSG00000001167',
#        ...
#        'ENSG00000251649', 'ENSG00000253229', 'ENSG00000255486',
#        'ENSG00000221498', 'ENSG00000222122', 'ENSG00000227029',
#        'ENSG00000239708', 'ENSG00000274532', 'ENSG00000277705',
#        'ENSG00000280139'],
#       dtype='object', name='Ensembl_GeneID', length=45947)

# %%
sc.pl.pca(adata, color='cell_type_category')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %% [markdown]
# Major jumps/points of inflection: PC1, PC8, PC12

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %% [markdown]
# @Zhongyu: UMAP tutorial continues from here: https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html#Embedding-the-neighborhood-graph
