# %%
import scanpy as sc
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad('control_annotated_data.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 96303 × 45947
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age'
#     var: 'HGNC_Alt_GeneID'

# %%
sc.pp.filter_cells(adata, min_genes=100, inplace=True)

# %%
sc.pp.filter_genes(adata, min_cells=3, inplace=True)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata = adata[:, adata.var.highly_variable]

# %%
print(adata)
# Out:
# View of AnnData object with n_obs × n_vars = 96303 × 4443
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age', 'n_genes'
#     var: 'HGNC_Alt_GeneID', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca(adata, color='cell_type_category')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['cell_type_category'])

# %%
sc.pl.umap(adata, color=['manuscript_id'])

# %%
print(adata.obsm['X_pca'].shape)
# Out:
# (96303, 50)

# %%
print(adata.obsm['X_umap'])
# Out:
# [[0.68940383 7.3411303 ]
#  [0.63464314 7.465102  ]
#  [0.8136006  4.4227896 ]
#  ...
#  [0.6800844  7.3724823 ]
#  [0.8197733  5.10335   ]
#  [0.55459595 7.5890455 ]]

# %%
sc.pl.umap(adata, color=['age'])

# %%
X = adata.obsm['X_pca'][:,0:40] #take first 40 pca as features
y = pd.factorize(adata.obs['cell_type_category'])[0] #factorize categories

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0) #split training set and testing set

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(penalty='l2', tol=1e-6, max_iter=int(1e6))
LR.fit(X_train, y_train)
print("Training Accuracy: ", LR.score(X_train, y_train))
print("Testing Accuracy: ", LR.score(X_test, y_test))
# Out:
# Training Accuracy:  0.9930427817005875
# Testing Accuracy:  0.9919005918798242

# %%
# import data again
adata = sc.read_h5ad('control_annotated_data.h5ad')
sc.pp.filter_cells(adata, min_genes=100, inplace=True)
sc.pp.filter_genes(adata, min_cells=3, inplace=True)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
adata = adata[:, adata.var.highly_variable]
print(adata)
# Out:
# View of AnnData object with n_obs × n_vars = 96303 × 4443
#     obs: 'cell_type_category', 'manuscript_id', 'subclass_id', 'disease', 'subject_id', 'age', 'n_genes'
#     var: 'HGNC_Alt_GeneID', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
subjects = pd.unique(adata.obs['subject_id']).to_list()
subjects
# Out:
# ['001C',
#  '002C',
#  '003C',
#  '222C',
#  '034C',
#  '065C',
#  '081C',
#  '084C',
#  '092C',
#  '098C',
#  '133C',
#  '1372C',
#  '137C',
#  '160C',
#  '192C',
#  '208C',
#  '218C',
#  '226C',
#  '244C',
#  '253C',
#  '296C',
#  '388C',
#  '396C',
#  '439C',
#  '454C',
#  '465C',
#  '483C',
#  '484C']

# %%
import anndata as ad
from sklearn.linear_model import LogisticRegression

# %%
train_acc = []
val_acc = []
for s in subjects:
    # test = adata[num[0]:num[-1]+1]
    # train_1 = adata[:num[0]]
    # train_2 = adata[num[-1]+1:]
    # train = ad.concat([train_1, train_2])
    train = adata[adata.obs['subject_id'] != s, :]
    test = adata[adata.obs['subject_id'] == s, :]
    # print(test,train,adata)
    sc.tl.pca(train, svd_solver='arpack')
    sc.tl.pca(test, svd_solver='arpack')
    X_train = train.obsm['X_pca'][:,0:40] #take first 40 pca as features
    y_train = pd.factorize(train.obs['cell_type_category'])[0] #factorize categories
    X_test = test.obsm['X_pca'][:,0:40] 
    y_test = pd.factorize(test.obs['cell_type_category'])[0]
    LR = LogisticRegression(penalty='l2', tol=1e-6, max_iter=int(1e6))
    LR.fit(X_train, y_train)
    print(f"subject: {s}")
    train_acc.append(LR.score(X_train, y_train))
    val_acc.append(LR.score(X_test, y_test))
    print("Training Accuracy: ", train_acc[-1])
    print("Testing Accuracy: ", val_acc[-1])
# Out:
# subject: 001C
# Training Accuracy:  0.992725617051916
# Testing Accuracy:  0.518796992481203
# subject: 002C
# Training Accuracy:  0.9928140330324362
# Testing Accuracy:  0.8571428571428571
# subject: 003C
# Training Accuracy:  0.9932143511088612
# Testing Accuracy:  0.7132947976878613
# subject: 222C
# Training Accuracy:  0.9930272759968907
# Testing Accuracy:  0.03798219584569733
# subject: 034C
# Training Accuracy:  0.9927612791196376
# Testing Accuracy:  0.669971671388102
# subject: 065C
# Training Accuracy:  0.9928087269646262
# Testing Accuracy:  0.6856080722251726
# subject: 081C
# Training Accuracy:  0.9928452282288268
# Testing Accuracy:  0.7219959266802444
# subject: 084C
# Training Accuracy:  0.9927785778389998
# Testing Accuracy:  0.5555555555555556
# subject: 092C
# Training Accuracy:  0.9924225952339537
# Testing Accuracy:  0.807131280388979
# subject: 098C
# Training Accuracy:  0.9931199246522633
# Testing Accuracy:  0.5320346320346321
# subject: 133C
# Training Accuracy:  0.9927282674356315
# Testing Accuracy:  0.8106467429371935
# subject: 1372C
# Training Accuracy:  0.992617874122214
# Testing Accuracy:  0.01001088139281828
# subject: 137C
# Training Accuracy:  0.9927180391169311
# Testing Accuracy:  0.09109109109109109
# subject: 160C
# Training Accuracy:  0.9927202981626382
# Testing Accuracy:  0.7476326800264259
# subject: 192C
# Training Accuracy:  0.9925765375237063
# Testing Accuracy:  0.7341112214498511
# subject: 208C
# Training Accuracy:  0.9927748424470049
# Testing Accuracy:  0.7784285017081504
# subject: 218C
# Training Accuracy:  0.9926322693484915
# Testing Accuracy:  0.7621812150114037
# subject: 226C
# Training Accuracy:  0.9927659027428799
# Testing Accuracy:  0.7995529061102832
# subject: 244C
# Training Accuracy:  0.9928643498340909
# Testing Accuracy:  0.4457831325301205
# subject: 253C
# Training Accuracy:  0.9927221627970385
# Testing Accuracy:  0.8243386243386244
# subject: 296C
# Training Accuracy:  0.9928172043010752
# Testing Accuracy:  0.7359975779594308
# subject: 388C
# Training Accuracy:  0.9926289142273655
# Testing Accuracy:  0.5579361609094884
# subject: 396C
# Training Accuracy:  0.9929394433629716
# Testing Accuracy:  0.8958990536277602
# subject: 439C
# Training Accuracy:  0.9931093304603505
# Testing Accuracy:  0.7464221203279144
# subject: 454C
# Training Accuracy:  0.9928000840866092
# Testing Accuracy:  0.0060189165950128975
# subject: 465C
# Training Accuracy:  0.992666602619528
# Testing Accuracy:  0.6304347826086957
# subject: 483C
# Training Accuracy:  0.9926915028097347
# Testing Accuracy:  0.7433056325023084
# subject: 484C
# Training Accuracy:  0.9929091424789638
# Testing Accuracy:  0.8162162162162162

# %%
import numpy as np
print("Average Training Accuracy: ", np.mean(train_acc))
print("Averahe Testing Accuracy: ", np.mean(val_acc))
# Out:
# Average Training Accuracy:  0.9927928706109157
# Averahe Testing Accuracy:  0.615554337099039

# %% [raw]
# # take '388C' as the validation individual
# num = []
# for i in range(adata.obs.shape[0]):
#     if adata.obs['subject_id'][i] == '388C':
#         num.append(i)
# print("range of '388C': ", num[0], "-", num[-1])

# %% [raw]
# test = adata[num[0]:num[-1]+1]
# train_1 = adata[:num[0]]
# train_2 = adata[num[-1]+1:]
# train = ad.concat([train_1, train_2])
# print(test,train,adata)

# %% [raw]
# sc.tl.pca(train, svd_solver='arpack')
# sc.tl.pca(test, svd_solver='arpack')

# %% [raw]
# X_train = train.obsm['X_pca'][:,0:40] #take first 40 pca as features
# y_train = pd.factorize(train.obs['cell_type_category'])[0] #factorize categories
# X_test = test.obsm['X_pca'][:,0:40]
# y_test = pd.factorize(test.obs['cell_type_category'])[0]

# %% [raw]
# from sklearn.linear_model import LogisticRegression
# LR = LogisticRegression(penalty='l2', tol=1e-6, max_iter=int(1e6))
# LR.fit(X_train, y_train)
# print("Training Accuracy: ", LR.score(X_train, y_train))
# print("Testing Accuracy: ", LR.score(X_test, y_test))
